# %% [markdown]
# ic crf

# %%
# !pwd
# Out:
# /home/eguan3/NLP_F25/hw-rnn/code

# %%
# !python3 ./tag.py ../data/icdev --train ../data/icsup --crf --model ../models/ic_crf_backprop.pkl --lr 0.1 --reg 0.01 --batch_size 1 --max_steps 2000
# Out:
# Warning: ../models/ic_crf_backprop.pkl already exists; will be overwritten at end of training
# Warning: won't load ../models/ic_crf_backprop.pkl: use --checkpoint for that
# INFO:corpus:Read 40 tokens from icsup
# INFO:corpus:Created 4 tag types
# INFO:corpus:Created 6 word types
# INFO:crf_backprop:Parameters: 32 = 4*4 + 4*4
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 32.40it/s]
# INFO:eval:Cross-entropy: 0.6747 nats (= perplexity 1.963)
# 100%|███████████████████████████████████████| 2000/2000 [00:24<00:00, 81.71it/s]
# INFO:crf:Average learning speed: 0.42 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 68.99it/s]
# INFO:eval:Cross-entropy: 0.3269 nats (= perplexity 1.387)
# INFO:hmm:Saved model to ../models/ic_crf_backprop.pkl
# INFO:eval:Total training time: 0:00:24
# ---
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 13.51it/s]
# INFO:eval:Wrote tagging to ../models/ic_crf_backprop_icdev.output
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 71.83it/s]
# INFO:eval:Cross-entropy: 0.3269 nats (= perplexity 1.387)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 13.87it/s]
# INFO:eval:Tagging accuracy: all: 87.879%, known: 87.879%, seen: nan%, novel: nan%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/icdev --model ../models/ic_crf_backprop.pkl
# Out:
# INFO:hmm:Loaded model from ../models/ic_crf_backprop.pkl
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 11.64it/s]
# INFO:eval:Wrote tagging to ../models/ic_crf_backprop_icdev.output
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 68.89it/s]
# INFO:eval:Cross-entropy: 0.3269 nats (= perplexity 1.387)
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 13.85it/s]
# INFO:eval:Tagging accuracy: all: 87.879%, known: 87.879%, seen: nan%, novel: nan%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/icsup --model ../models/ic_crf_backprop.pkl
# Out:
# INFO:hmm:Loaded model from ../models/ic_crf_backprop.pkl
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/eguan3/NLP_F25/hw-rnn/code/./tag.py", line 410, in <module>
#     main()
#   File "/home/eguan3/NLP_F25/hw-rnn/code/./tag.py", line 401, in main
#     write_tagging(model, eval_corpus, Path(args.output_file))
#   File "/home/eguan3/NLP_F25/hw-rnn/code/eval.py", line 115, in write_tagging
#     predicted = tagger(gold.desupervise())
#   File "/home/eguan3/NLP_F25/hw-rnn/code/eval.py", line 22, in tagger
#     return model.viterbi_tagging(input, eval_corpus)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/hmm.py", line 373, in viterbi_tagging
#     self.setup_sentence(isent)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf.py", line 339, in setup_sentence
#     embs = self.lexicon.embs(isent)   # shape: [T, emb_dim]
#   File "/etc/conda/envs/nlp-class/lib/python3.9/site-packages/torch/nn/modules/module.py", line 1614, in __getattr__
#     raise AttributeError("'{}' object has no attribute '{}'".format(
# AttributeError: 'ConditionalRandomFieldBackprop' object has no attribute 'lexicon'

# %% [markdown]
# en crf

# %%
# !python3 tag.py ../data/endev --train ../data/ensup --crf --model ../models/en_crf_backprop.pkl --lr 0.05 --reg 0.1 --batch_size 5 --max_steps 20000
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:crf_backprop:Parameters: 324740 = 26*12464 + 26*26
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 90.37it/s]
# INFO:eval:Cross-entropy: 3.0514 nats (= perplexity 21.144)
# 100%|███████████████████████████████████████| 2000/2000 [01:32<00:00, 21.71it/s]
# INFO:crf:Average learning speed: 1.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 90.33it/s]
# INFO:eval:Cross-entropy: 0.6018 nats (= perplexity 1.825)
# 100%|███████████████████████████████████████| 2000/2000 [01:31<00:00, 21.88it/s]
# INFO:crf:Average learning speed: 0.98 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 84.78it/s]
# INFO:eval:Cross-entropy: 0.4839 nats (= perplexity 1.622)
#  89%|██████████████████████████████████▌    | 1775/2000 [01:22<00:10, 22.01it/s]INFO:hmm:Saved model to ../models/en_crf_backprop-5780.pkl
# 100%|███████████████████████████████████████| 2000/2000 [01:32<00:00, 21.64it/s]
# INFO:crf:Average learning speed: 0.78 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:10<00:00, 90.64it/s]
# INFO:eval:Cross-entropy: 0.4283 nats (= perplexity 1.535)
# 100%|███████████████████████████████████████| 2000/2000 [01:26<00:00, 23.18it/s]
# INFO:crf:Average learning speed: 0.74 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:10<00:00, 94.75it/s]
# INFO:eval:Cross-entropy: 0.3908 nats (= perplexity 1.478)
# 100%|███████████████████████████████████████| 2000/2000 [01:25<00:00, 23.35it/s]
# INFO:crf:Average learning speed: 0.66 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 89.23it/s]
# INFO:eval:Cross-entropy: 0.3651 nats (= perplexity 1.441)
#  94%|████████████████████████████████████▌  | 1875/2000 [01:25<00:05, 22.52it/s]INFO:hmm:Saved model to ../models/en_crf_backprop-11880.pkl
# 100%|███████████████████████████████████████| 2000/2000 [01:30<00:00, 22.14it/s]
# INFO:crf:Average learning speed: 0.61 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 87.93it/s]
# INFO:eval:Cross-entropy: 0.3451 nats (= perplexity 1.412)
# 100%|███████████████████████████████████████| 2000/2000 [01:38<00:00, 20.29it/s]
# INFO:crf:Average learning speed: 0.54 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 89.06it/s]
# INFO:eval:Cross-entropy: 0.3299 nats (= perplexity 1.391)
# 100%|███████████████████████████████████████| 2000/2000 [01:36<00:00, 20.74it/s]
# INFO:crf:Average learning speed: 0.54 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 90.11it/s]
# INFO:eval:Cross-entropy: 0.3148 nats (= perplexity 1.370)
#  70%|███████████████████████████▍           | 1410/2000 [01:06<00:34, 17.02it/s]INFO:hmm:Saved model to ../models/en_crf_backprop-17415.pkl
# 100%|███████████████████████████████████████| 2000/2000 [01:34<00:00, 21.09it/s]
# INFO:crf:Average learning speed: 0.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:10<00:00, 93.74it/s]
# INFO:eval:Cross-entropy: 0.3032 nats (= perplexity 1.354)
# 100%|███████████████████████████████████████| 2000/2000 [01:36<00:00, 20.66it/s]
# INFO:crf:Average learning speed: 0.48 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [00:10<00:00, 92.24it/s]
# INFO:eval:Cross-entropy: 0.2956 nats (= perplexity 1.344)
# INFO:hmm:Saved model to ../models/en_crf_backprop.pkl
# INFO:eval:Total training time: 0:17:26
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:38<00:00, 25.90it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_backprop_endev.output
# 100%|█████████████████████████████████████████| 996/996 [00:10<00:00, 91.32it/s]
# INFO:eval:Cross-entropy: 0.2956 nats (= perplexity 1.344)
# 100%|█████████████████████████████████████████| 996/996 [00:38<00:00, 25.75it/s]
# INFO:eval:Tagging accuracy: all: 90.133%, known: 92.583%, seen: nan%, novel: 64.753%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/endev --model ../models/en_crf_backprop.pkl
# Out:
# INFO:hmm:Loaded model from ../models/en_crf_backprop.pkl
# 100%|█████████████████████████████████████████| 996/996 [00:38<00:00, 25.59it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_backprop_endev.output
# 100%|█████████████████████████████████████████| 996/996 [00:11<00:00, 90.26it/s]
# INFO:eval:Cross-entropy: 0.2956 nats (= perplexity 1.344)
# 100%|█████████████████████████████████████████| 996/996 [00:38<00:00, 25.95it/s]
# INFO:eval:Tagging accuracy: all: 90.133%, known: 92.583%, seen: nan%, novel: 64.753%
# INFO:eval:===

# %% [markdown]
# birnn crf

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup \
    --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-200.txt \
    --lr 0.01 --reg 0.1 --batch_size 5 \
    --model ../models/en_crf_birnn.pkl \
    --eval_interval 2000 --max_steps 50000
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-200.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 5856 = 8*209 + 8*209 + 8*69 + 8*243 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.30it/s]
# INFO:eval:Cross-entropy: 3.1039 nats (= perplexity 22.285)
#  46%|██████████████████▍                     | 924/2000 [03:22<03:38,  4.91it/s]INFO:hmm:Saved model to ../models/en_crf_birnn-925.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:12<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 2.7 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.10it/s]
# INFO:eval:Cross-entropy: 0.3503 nats (= perplexity 1.420)
#   0%|                                          | 4/2000 [00:00<05:52,  5.67it/s]INFO:hmm:Saved model to ../models/en_crf_birnn-2005.pkl
#  70%|███████████████████████████▍           | 1409/2000 [05:01<02:14,  4.41it/s]INFO:hmm:Saved model to ../models/en_crf_birnn-3410.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:11<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 3.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.07it/s]
# INFO:eval:Cross-entropy: 0.2624 nats (= perplexity 1.300)
#  17%|██████▋                                 | 333/2000 [01:11<05:39,  4.91it/s]INFO:hmm:Saved model to ../models/en_crf_birnn-4335.pkl
#  87%|█████████████████████████████████▉     | 1739/2000 [06:12<00:48,  5.33it/s]INFO:hmm:Saved model to ../models/en_crf_birnn-5740.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:09<00:00,  4.66it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.18it/s]
# INFO:eval:Cross-entropy: 0.2433 nats (= perplexity 1.275)
#  34%|█████████████▊                          | 689/2000 [02:25<03:46,  5.79it/s]INFO:hmm:Saved model to ../models/en_crf_birnn-6690.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:12<00:00,  4.62it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.26it/s]
# INFO:eval:Cross-entropy: 0.2449 nats (= perplexity 1.278)
# INFO:hmm:Saved model to ../models/en_crf_birnn.pkl
# INFO:eval:Total training time: 0:36:55
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:52<00:00, 19.06it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.06it/s]
# INFO:eval:Cross-entropy: 0.2449 nats (= perplexity 1.278)
# 100%|█████████████████████████████████████████| 996/996 [00:49<00:00, 20.22it/s]
# INFO:eval:Tagging accuracy: all: 92.317%, known: 93.769%, seen: 78.992%, novel: 75.865%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/endev --model ../models/en_crf_birnn.pkl
# Out:
# INFO:hmm:Loaded model from ../models/en_crf_birnn.pkl
# 100%|█████████████████████████████████████████| 996/996 [00:57<00:00, 17.42it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:39<00:00,  9.98it/s]
# INFO:eval:Cross-entropy: 0.2449 nats (= perplexity 1.278)
# 100%|█████████████████████████████████████████| 996/996 [00:50<00:00, 19.62it/s]
# INFO:eval:Tagging accuracy: all: 92.317%, known: 93.151%, seen: nan%, novel: 75.865%
# INFO:eval:===

# %% [markdown]
# testing

# %% [markdown]
# rnn dimension

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 4 \
    --lexicon ../lexicons/words-10.txt --lr 0.01 --reg 0.1 \
    --batch_size 5 --model ../models/en_crf_birnn_rnn4.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 552 = 4*15 + 4*15 + 4*61 + 4*45 + 4 + 4
# 100%|█████████████████████████████████████████| 996/996 [01:32<00:00, 10.78it/s]
# INFO:eval:Cross-entropy: 3.0816 nats (= perplexity 21.794)
#  49%|███████████████████▌                    | 979/2000 [03:27<02:26,  6.98it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-980.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:57<00:00,  4.79it/s]
# INFO:crf:Average learning speed: 2.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:31<00:00, 10.93it/s]
# INFO:eval:Cross-entropy: 1.2050 nats (= perplexity 3.337)
#   0%|                                          | 4/2000 [00:00<05:43,  5.81it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-2005.pkl
#  74%|████████████████████████████▊          | 1479/2000 [05:01<01:27,  5.96it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-3480.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:49<00:00,  4.89it/s]
# INFO:crf:Average learning speed: 5.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:31<00:00, 10.94it/s]
# INFO:eval:Cross-entropy: 0.9067 nats (= perplexity 2.476)
#  25%|██████████▏                             | 508/2000 [01:41<05:54,  4.21it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-4510.pkl
# 100%|██████████████████████████████████████▉| 1999/2000 [06:42<00:00,  5.72it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-6000.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:42<00:00,  4.97it/s]
# INFO:crf:Average learning speed: 8.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:31<00:00, 10.84it/s]
# INFO:eval:Cross-entropy: 0.8339 nats (= perplexity 2.302)
#  51%|███████████████████▊                   | 1014/2000 [03:28<02:46,  5.92it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-7015.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:51<00:00,  4.86it/s]
# INFO:crf:Average learning speed: 10 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:32<00:00, 10.80it/s]
# INFO:eval:Cross-entropy: 0.7911 nats (= perplexity 2.206)
#   1%|▍                                        | 24/2000 [00:04<05:12,  6.31it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-8025.pkl
#  75%|█████████████████████████████▍         | 1509/2000 [05:04<01:15,  6.53it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-9510.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:46<00:00,  4.92it/s]
# INFO:crf:Average learning speed: 12 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:33<00:00, 10.61it/s]
# INFO:eval:Cross-entropy: 0.7834 nats (= perplexity 2.189)
#  26%|██████████▍                             | 519/2000 [01:45<04:31,  5.46it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-10520.pkl
#  98%|██████████████████████████████████████▎| 1964/2000 [06:45<00:06,  5.76it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-11965.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:52<00:00,  4.84it/s]
# INFO:crf:Average learning speed: 11 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:32<00:00, 10.75it/s]
# INFO:eval:Cross-entropy: 0.7766 nats (= perplexity 2.174)
#  49%|███████████████████▌                    | 979/2000 [03:20<02:27,  6.92it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-12980.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:46<00:00,  4.92it/s]
# INFO:crf:Average learning speed: 11 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:32<00:00, 10.81it/s]
# INFO:eval:Cross-entropy: 0.7668 nats (= perplexity 2.153)
#   1%|▍                                        | 19/2000 [00:03<05:31,  5.98it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-14020.pkl
#  74%|████████████████████████████▊          | 1479/2000 [05:03<01:40,  5.18it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-15480.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:52<00:00,  4.85it/s]
# INFO:crf:Average learning speed: 12 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:32<00:00, 10.78it/s]
# INFO:eval:Cross-entropy: 0.7539 nats (= perplexity 2.125)
#  25%|█████████▉                              | 499/2000 [01:39<03:56,  6.35it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-16500.pkl
#  98%|██████████████████████████████████████▍| 1968/2000 [06:40<00:07,  4.16it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4-17970.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:48<00:00,  4.89it/s]
# INFO:crf:Average learning speed: 12 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:33<00:00, 10.69it/s]
# INFO:eval:Cross-entropy: 0.7696 nats (= perplexity 2.159)
# INFO:hmm:Saved model to ../models/en_crf_birnn_rnn4.pkl
# INFO:eval:Total training time: 1:16:50
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:48<00:00, 20.62it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_rnn4_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:32<00:00, 10.76it/s]
# INFO:eval:Cross-entropy: 0.7696 nats (= perplexity 2.159)
# 100%|█████████████████████████████████████████| 996/996 [00:47<00:00, 20.81it/s]
# INFO:eval:Tagging accuracy: all: 70.976%, known: 72.135%, seen: 53.676%, novel: 63.322%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 16 \
    --lexicon ../lexicons/words-10.txt --lr 0.005 --reg 0.1 \
    --batch_size 5 --model ../models/en_crf_birnn_rnn16.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 3360 = 16*27 + 16*27 + 16*85 + 16*69 + 16 + 16
# 100%|█████████████████████████████████████████| 996/996 [01:41<00:00,  9.79it/s]
# INFO:eval:Cross-entropy: 3.2621 nats (= perplexity 26.103)
#  43%|█████████████████                       | 854/2000 [03:17<04:18,  4.44it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-855.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:41<00:00,  4.34it/s]
# INFO:crf:Average learning speed: 0.81 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:42<00:00,  9.74it/s]
# INFO:eval:Cross-entropy: 1.0014 nats (= perplexity 2.722)
#   0%|                                          | 4/2000 [00:00<06:01,  5.52it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-2005.pkl
#  67%|██████████████████████████             | 1334/2000 [05:01<02:20,  4.73it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-3335.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:35<00:00,  4.39it/s]
# INFO:crf:Average learning speed: 1.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:42<00:00,  9.75it/s]
# INFO:eval:Cross-entropy: 0.6703 nats (= perplexity 1.955)
#  10%|███▉                                    | 194/2000 [00:44<05:55,  5.07it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-4195.pkl
#  75%|█████████████████████████████▍         | 1509/2000 [05:45<01:37,  5.02it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-5510.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:40<00:00,  4.34it/s]
# INFO:crf:Average learning speed: 2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:41<00:00,  9.77it/s]
# INFO:eval:Cross-entropy: 0.5672 nats (= perplexity 1.763)
#  18%|███████▏                                | 359/2000 [01:23<05:04,  5.38it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-6360.pkl
#  82%|███████████████████████████████▊       | 1634/2000 [06:23<01:25,  4.27it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-7635.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:46<00:00,  4.29it/s]
# INFO:crf:Average learning speed: 2.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:40<00:00,  9.86it/s]
# INFO:eval:Cross-entropy: 0.5051 nats (= perplexity 1.657)
#  26%|██████████▍                             | 524/2000 [01:56<04:32,  5.42it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-8525.pkl
#  93%|████████████████████████████████████▎  | 1859/2000 [06:57<00:26,  5.42it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-9860.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:29<00:00,  4.45it/s]
# INFO:crf:Average learning speed: 2.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:41<00:00,  9.84it/s]
# INFO:eval:Cross-entropy: 0.4784 nats (= perplexity 1.613)
#  37%|██████████████▋                         | 734/2000 [02:47<03:59,  5.28it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-10735.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:42<00:00,  4.32it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:41<00:00,  9.77it/s]
# INFO:eval:Cross-entropy: 0.4550 nats (= perplexity 1.576)
#   0%|                                          | 4/2000 [00:00<06:20,  5.25it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-12005.pkl
#  65%|█████████████████████████▏             | 1294/2000 [05:01<03:01,  3.90it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-13295.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:40<00:00,  4.34it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:41<00:00,  9.79it/s]
# INFO:eval:Cross-entropy: 0.4447 nats (= perplexity 1.560)
#   9%|███▌                                    | 179/2000 [00:39<04:50,  6.26it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-14180.pkl
#  74%|████████████████████████████▊          | 1479/2000 [05:39<01:58,  4.40it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-15480.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:48<00:00,  4.27it/s]
# INFO:crf:Average learning speed: 2.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:46<00:00,  9.39it/s]
# INFO:eval:Cross-entropy: 0.4242 nats (= perplexity 1.528)
#  14%|█████▌                                  | 279/2000 [01:05<05:26,  5.27it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-16280.pkl
#  79%|██████████████████████████████▋        | 1573/2000 [06:05<01:18,  5.42it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-17575.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:51<00:00,  4.24it/s]
# INFO:crf:Average learning speed: 2.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:40<00:00,  9.91it/s]
# INFO:eval:Cross-entropy: 0.4150 nats (= perplexity 1.514)
#  20%|████████▏                               | 409/2000 [01:34<05:27,  4.86it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-18410.pkl
#  83%|████████████████████████████████▎      | 1658/2000 [06:35<01:26,  3.97it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16-19660.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:56<00:00,  4.20it/s]
# INFO:crf:Average learning speed: 2.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:42<00:00,  9.70it/s]
# INFO:eval:Cross-entropy: 0.4183 nats (= perplexity 1.519)
# INFO:hmm:Saved model to ../models/en_crf_birnn_rnn16.pkl
# INFO:eval:Total training time: 1:35:55
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:55<00:00, 17.97it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_rnn16_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:42<00:00,  9.69it/s]
# INFO:eval:Cross-entropy: 0.4183 nats (= perplexity 1.519)
# 100%|█████████████████████████████████████████| 996/996 [00:53<00:00, 18.67it/s]
# INFO:eval:Tagging accuracy: all: 84.638%, known: 85.834%, seen: 67.542%, novel: 76.125%
# INFO:eval:===

# %% [markdown]
# lr

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-10.txt --lr 0.005 \
    --batch_size 5 --model ../models/en_crf_birnn_lr0005.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 1296 = 8*19 + 8*19 + 8*69 + 8*53 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:40<00:00,  9.91it/s]
# INFO:eval:Cross-entropy: 3.2114 nats (= perplexity 24.815)
#  46%|██████████████████▎                     | 914/2000 [03:19<03:04,  5.90it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-915.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:14<00:00,  4.61it/s]
# INFO:crf:Average learning speed: 0.63 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.31it/s]
# INFO:eval:Cross-entropy: 1.3035 nats (= perplexity 3.682)
#   0%|                                          | 4/2000 [00:00<06:59,  4.76it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-2005.pkl
#  70%|███████████████████████████▏           | 1394/2000 [05:00<01:30,  6.71it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-3395.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:16<00:00,  4.58it/s]
# INFO:crf:Average learning speed: 1.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.41it/s]
# INFO:eval:Cross-entropy: 0.9078 nats (= perplexity 2.479)
#  16%|██████▍                                 | 323/2000 [01:09<04:54,  5.69it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-4325.pkl
#  87%|██████████████████████████████████     | 1747/2000 [06:09<00:58,  4.30it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-5750.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:02<00:00,  4.73it/s]
# INFO:crf:Average learning speed: 1.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.27it/s]
# INFO:eval:Cross-entropy: 0.7630 nats (= perplexity 2.145)
#  36%|██████████████▎                         | 714/2000 [02:30<03:14,  6.62it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-6715.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:09<00:00,  4.66it/s]
# INFO:crf:Average learning speed: 1.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.51it/s]
# INFO:eval:Cross-entropy: 0.6904 nats (= perplexity 1.995)
#   0%|                                          | 4/2000 [00:00<02:29, 13.34it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-8005.pkl
#  72%|████████████████████████████▏          | 1444/2000 [05:01<01:25,  6.48it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-9445.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:59<00:00,  4.77it/s]
# INFO:crf:Average learning speed: 2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.53it/s]
# INFO:eval:Cross-entropy: 0.6540 nats (= perplexity 1.923)
#  21%|████████▍                               | 419/2000 [01:27<04:36,  5.71it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-10420.pkl
#  90%|███████████████████████████████████    | 1799/2000 [06:28<00:33,  5.93it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-11800.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:07<00:00,  4.68it/s]
# INFO:crf:Average learning speed: 2.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.11it/s]
# INFO:eval:Cross-entropy: 0.6227 nats (= perplexity 1.864)
#  38%|███████████████▏                        | 759/2000 [02:42<04:05,  5.05it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-12760.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:03<00:00,  4.72it/s]
# INFO:crf:Average learning speed: 2.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.26it/s]
# INFO:eval:Cross-entropy: 0.6087 nats (= perplexity 1.838)
#   0%|                                          | 4/2000 [00:00<05:22,  6.19it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-14005.pkl
#  69%|███████████████████████████            | 1388/2000 [05:00<01:58,  5.18it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-15390.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:14<00:00,  4.60it/s]
# INFO:crf:Average learning speed: 2.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.16it/s]
# INFO:eval:Cross-entropy: 0.5886 nats (= perplexity 1.802)
#  16%|██████▎                                 | 314/2000 [01:08<04:22,  6.43it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-16315.pkl
#  86%|█████████████████████████████████▌     | 1719/2000 [06:09<00:54,  5.16it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-17720.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:14<00:00,  4.61it/s]
# INFO:crf:Average learning speed: 2.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.30it/s]
# INFO:eval:Cross-entropy: 0.5762 nats (= perplexity 1.779)
#  33%|█████████████                           | 654/2000 [02:19<04:01,  5.57it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-18655.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:12<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 2.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.39it/s]
# INFO:eval:Cross-entropy: 0.5635 nats (= perplexity 1.757)
#   0%|                                          | 3/2000 [00:00<06:58,  4.77it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-20005.pkl
#  69%|██████████████████████████▉            | 1379/2000 [05:01<02:18,  4.47it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-21380.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:13<00:00,  4.61it/s]
# INFO:crf:Average learning speed: 2.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.24it/s]
# INFO:eval:Cross-entropy: 0.5544 nats (= perplexity 1.741)
#  17%|██████▊                                 | 338/2000 [01:11<05:31,  5.02it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-22340.pkl
#  87%|█████████████████████████████████▉     | 1738/2000 [06:12<00:48,  5.36it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-23740.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:08<00:00,  4.67it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.35it/s]
# INFO:eval:Cross-entropy: 0.5464 nats (= perplexity 1.727)
#  35%|█████████████▉                          | 694/2000 [02:28<03:20,  6.52it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-24695.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:15<00:00,  4.60it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.42it/s]
# INFO:eval:Cross-entropy: 0.5388 nats (= perplexity 1.714)
#   0%|                                          | 4/2000 [00:00<07:20,  4.53it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-26005.pkl
#  71%|███████████████████████████▊           | 1424/2000 [05:01<01:33,  6.15it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-27425.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:04<00:00,  4.71it/s]
# INFO:crf:Average learning speed: 2.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.26it/s]
# INFO:eval:Cross-entropy: 0.5309 nats (= perplexity 1.700)
#  18%|███████▎                                | 368/2000 [01:20<05:34,  4.88it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-28370.pkl
#  89%|██████████████████████████████████▌    | 1773/2000 [06:20<00:45,  4.94it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-29775.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:09<00:00,  4.65it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.30it/s]
# INFO:eval:Cross-entropy: 0.5253 nats (= perplexity 1.691)
#  37%|██████████████▊                         | 738/2000 [02:35<04:21,  4.83it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-30740.pkl
# 100%|███████████████████████████████████████| 2000/2000 [06:59<00:00,  4.77it/s]
# INFO:crf:Average learning speed: 2.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.26it/s]
# INFO:eval:Cross-entropy: 0.5210 nats (= perplexity 1.684)
#   0%|                                          | 4/2000 [00:00<05:18,  6.27it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-32005.pkl
#  70%|███████████████████████████▍           | 1409/2000 [05:01<01:33,  6.32it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-33410.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:08<00:00,  4.67it/s]
# INFO:crf:Average learning speed: 2.7 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.18it/s]
# INFO:eval:Cross-entropy: 0.5159 nats (= perplexity 1.675)
#  18%|███████▏                                | 359/2000 [01:16<04:32,  6.03it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-34360.pkl
#  88%|██████████████████████████████████▏    | 1753/2000 [06:16<00:45,  5.39it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-35755.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:11<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 2.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.49it/s]
# INFO:eval:Cross-entropy: 0.5073 nats (= perplexity 1.661)
#  35%|█████████████▉                          | 694/2000 [02:30<03:25,  6.37it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005-36695.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:09<00:00,  4.66it/s]
# INFO:crf:Average learning speed: 2.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.16it/s]
# INFO:eval:Cross-entropy: 0.5078 nats (= perplexity 1.662)
# INFO:hmm:Saved model to ../models/en_crf_birnn_lr0005.pkl
# INFO:eval:Total training time: 2:48:12
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:49<00:00, 20.02it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_lr0005_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.22it/s]
# INFO:eval:Cross-entropy: 0.5078 nats (= perplexity 1.662)
# 100%|█████████████████████████████████████████| 996/996 [00:49<00:00, 19.94it/s]
# INFO:eval:Tagging accuracy: all: 81.143%, known: 82.267%, seen: 64.916%, novel: 73.270%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-10.txt --lr 0.02 \
    --batch_size 5 --model ../models/en_crf_birnn_lr002.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 1296 = 8*19 + 8*19 + 8*69 + 8*53 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.43it/s]
# INFO:eval:Cross-entropy: 3.2114 nats (= perplexity 24.815)
#  46%|██████████████████▍                     | 924/2000 [03:24<03:46,  4.75it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_lr002-925.pkl
#  86%|█████████████████████████████████▋     | 1730/2000 [06:21<00:59,  4.53it/s]
# Traceback (most recent call last):
#   File "/home/eguan3/NLP_F25/hw-rnn/code/./tag.py", line 410, in <module>
#     main()
#   File "/home/eguan3/NLP_F25/hw-rnn/code/./tag.py", line 368, in main
#     model.train(corpus=train_corpus,
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf_backprop.py", line 143, in train
#     super().train(corpus, *args, minibatch_size=minibatch_size, lr=lr, reg=reg, **kwargs)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf.py", line 183, in train
#     self.accumulate_logprob_gradient(sentence, corpus)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf_neural.py", line 166, in accumulate_logprob_gradient
#     super().accumulate_logprob_gradient(sentence, corpus)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf_backprop.py", line 169, in accumulate_logprob_gradient
#     logprob = self.logprob(sentence, corpus)
#   File "/etc/conda/envs/nlp-class/lib/python3.9/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf.py", line 232, in logprob
#     normalizer = super().logprob(sentence.desupervise(), corpus)
#   File "/etc/conda/envs/nlp-class/lib/python3.9/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/hmm.py", line 540, in logprob
#     return self.forward_pass(isent)
#   File "/etc/conda/envs/nlp-class/lib/python3.9/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/hmm.py", line 273, in forward_pass
#     A = self.A_at(j, isent)
#   File "/etc/conda/envs/nlp-class/lib/python3.9/site-packages/typeguard/__init__.py", line 1033, in wrapper
#     retval = func(*args, **kwargs)
#   File "/home/eguan3/NLP_F25/hw-rnn/code/crf_neural.py", line 196, in A_at
#     ones = one.view(1, 1, 1).expand(k, k, 1)
#   File "/etc/conda/envs/nlp-class/lib/python3.9/site-packages/torch/utils/_device.py", line 58, in __torch_function__
#     def __torch_function__(self, func, types, args=(), kwargs=None):
# KeyboardInterrupt
# ^C

# %% [markdown]
# regularization

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-10.txt --lr 0.01 --reg 0.0 \
    --batch_size 5 --model ../models/en_crf_birnn_reg0.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 1296 = 8*19 + 8*19 + 8*69 + 8*53 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.44it/s]
# INFO:eval:Cross-entropy: 3.2114 nats (= perplexity 24.815)
#  47%|██████████████████▊                     | 939/2000 [03:24<03:41,  4.80it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-940.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:10<00:00,  4.65it/s]
# INFO:crf:Average learning speed: 1.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.35it/s]
# INFO:eval:Cross-entropy: 0.9557 nats (= perplexity 2.600)
#   0%|                                          | 4/2000 [00:00<05:14,  6.35it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-2005.pkl
#  71%|███████████████████████████▌           | 1413/2000 [05:01<02:07,  4.60it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-3415.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:06<00:00,  4.69it/s]
# INFO:crf:Average learning speed: 3.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.31it/s]
# INFO:eval:Cross-entropy: 0.7213 nats (= perplexity 2.057)
#  19%|███████▌                                | 379/2000 [01:19<04:38,  5.81it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-4380.pkl
#  90%|██████████████████████████████████▉    | 1794/2000 [06:19<00:37,  5.49it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-5795.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:03<00:00,  4.72it/s]
# INFO:crf:Average learning speed: 4.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.46it/s]
# INFO:eval:Cross-entropy: 0.6529 nats (= perplexity 1.921)
#  38%|███████████████▎                        | 764/2000 [02:41<03:47,  5.44it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-6765.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:08<00:00,  4.67it/s]
# INFO:crf:Average learning speed: 4.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.49it/s]
# INFO:eval:Cross-entropy: 0.5996 nats (= perplexity 1.821)
#   0%|                                          | 4/2000 [00:00<02:53, 11.51it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-8005.pkl
#  70%|███████████████████████████▍           | 1409/2000 [05:01<01:29,  6.58it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-9410.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:07<00:00,  4.67it/s]
# INFO:crf:Average learning speed: 4.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.32it/s]
# INFO:eval:Cross-entropy: 0.5727 nats (= perplexity 1.773)
#  18%|███████▍                                | 369/2000 [01:17<05:35,  4.86it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-10370.pkl
#  86%|█████████████████████████████████▌     | 1719/2000 [06:17<00:51,  5.44it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-11720.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:15<00:00,  4.60it/s]
# INFO:crf:Average learning speed: 4.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.38it/s]
# INFO:eval:Cross-entropy: 0.5572 nats (= perplexity 1.746)
#  35%|█████████████▉                          | 694/2000 [02:27<04:11,  5.19it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-12695.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:02<00:00,  4.73it/s]
# INFO:crf:Average learning speed: 5.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.44it/s]
# INFO:eval:Cross-entropy: 0.5492 nats (= perplexity 1.732)
#   0%|                                          | 4/2000 [00:00<03:48,  8.74it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-14005.pkl
#  70%|███████████████████████████▏           | 1393/2000 [05:00<01:46,  5.70it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-15395.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:16<00:00,  4.58it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.47it/s]
# INFO:eval:Cross-entropy: 0.5316 nats (= perplexity 1.702)
#  16%|██████▍                                 | 324/2000 [01:08<04:42,  5.93it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-16325.pkl
#  88%|██████████████████████████████████▍    | 1764/2000 [06:09<00:37,  6.33it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-17765.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:03<00:00,  4.72it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.46it/s]
# INFO:eval:Cross-entropy: 0.5282 nats (= perplexity 1.696)
#  36%|██████████████▎                         | 714/2000 [02:30<03:38,  5.89it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-18715.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:10<00:00,  4.64it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.38it/s]
# INFO:eval:Cross-entropy: 0.5252 nats (= perplexity 1.691)
#   0%|                                          | 4/2000 [00:00<06:26,  5.17it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-20005.pkl
#  71%|███████████████████████████▋           | 1419/2000 [05:01<01:39,  5.82it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-21420.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:04<00:00,  4.71it/s]
# INFO:crf:Average learning speed: 5.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.45it/s]
# INFO:eval:Cross-entropy: 0.5105 nats (= perplexity 1.666)
#  20%|███████▊                                | 393/2000 [01:22<05:34,  4.81it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-22395.pkl
#  90%|███████████████████████████████████▏   | 1804/2000 [06:22<00:29,  6.72it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-23805.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:05<00:00,  4.70it/s]
# INFO:crf:Average learning speed: 5.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:33<00:00, 10.62it/s]
# INFO:eval:Cross-entropy: 0.5090 nats (= perplexity 1.664)
#  39%|███████████████▌                        | 779/2000 [02:44<03:13,  6.32it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-24780.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:11<00:00,  4.64it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.29it/s]
# INFO:eval:Cross-entropy: 0.5026 nats (= perplexity 1.653)
#   0%|                                          | 4/2000 [00:00<05:56,  5.60it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-26005.pkl
#  71%|███████████████████████████▋           | 1419/2000 [05:01<01:20,  7.24it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-27420.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:01<00:00,  4.74it/s]
# INFO:crf:Average learning speed: 4.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.51it/s]
# INFO:eval:Cross-entropy: 0.4972 nats (= perplexity 1.644)
#  20%|███████▉                                | 398/2000 [01:25<04:12,  6.33it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-28400.pkl
#  90%|███████████████████████████████████▎   | 1809/2000 [06:26<00:33,  5.64it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-29810.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:05<00:00,  4.70it/s]
# INFO:crf:Average learning speed: 5.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.48it/s]
# INFO:eval:Cross-entropy: 0.4927 nats (= perplexity 1.637)
#  39%|███████████████▌                        | 779/2000 [02:46<04:09,  4.89it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg0-30780.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:04<00:00,  4.72it/s]
# INFO:crf:Average learning speed: 5.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.36it/s]
# INFO:eval:Cross-entropy: 0.4956 nats (= perplexity 1.641)
# INFO:hmm:Saved model to ../models/en_crf_birnn_reg0.pkl
# INFO:eval:Total training time: 2:21:03
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:50<00:00, 19.82it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_reg0_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.30it/s]
# INFO:eval:Cross-entropy: 0.4956 nats (= perplexity 1.641)
# 100%|█████████████████████████████████████████| 996/996 [00:52<00:00, 19.07it/s]
# INFO:eval:Tagging accuracy: all: 81.093%, known: 82.066%, seen: 66.176%, novel: 75.000%
# INFO:eval:===

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-10.txt --lr 0.01 --reg 0.2 \
    --batch_size 5 --model ../models/en_crf_birnn_reg02.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 1296 = 8*19 + 8*19 + 8*69 + 8*53 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.32it/s]
# INFO:eval:Cross-entropy: 3.2114 nats (= perplexity 24.815)
#  46%|██████████████████▎                     | 914/2000 [03:23<03:12,  5.65it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-915.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:22<00:00,  4.52it/s]
# INFO:crf:Average learning speed: 1.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.22it/s]
# INFO:eval:Cross-entropy: 0.9574 nats (= perplexity 2.605)
#   0%|                                          | 4/2000 [00:00<06:47,  4.90it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-2005.pkl
#  69%|██████████████████████████▉            | 1384/2000 [05:01<01:53,  5.45it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-3385.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:15<00:00,  4.59it/s]
# INFO:crf:Average learning speed: 3.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.37it/s]
# INFO:eval:Cross-entropy: 0.7206 nats (= perplexity 2.056)
#  16%|██████▍                                 | 323/2000 [01:10<04:50,  5.78it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-4325.pkl
#  86%|█████████████████████████████████▍     | 1714/2000 [06:10<00:42,  6.79it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-5715.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:13<00:00,  4.62it/s]
# INFO:crf:Average learning speed: 4.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.08it/s]
# INFO:eval:Cross-entropy: 0.6519 nats (= perplexity 1.919)
#  32%|████████████▉                           | 648/2000 [02:18<03:11,  7.07it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-6650.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:14<00:00,  4.60it/s]
# INFO:crf:Average learning speed: 4.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.52it/s]
# INFO:eval:Cross-entropy: 0.6004 nats (= perplexity 1.823)
#   0%|                                          | 4/2000 [00:00<02:28, 13.41it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-8005.pkl
#  72%|███████████████████████████▉           | 1434/2000 [05:01<01:25,  6.60it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-9435.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:08<00:00,  4.67it/s]
# INFO:crf:Average learning speed: 4.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.38it/s]
# INFO:eval:Cross-entropy: 0.5710 nats (= perplexity 1.770)
#  18%|███████                                 | 354/2000 [01:17<05:57,  4.60it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-10355.pkl
#  82%|███████████████████████████████▊       | 1634/2000 [06:16<01:32,  3.96it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-11635.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:38<00:00,  4.36it/s]
# INFO:crf:Average learning speed: 4.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.35it/s]
# INFO:eval:Cross-entropy: 0.5569 nats (= perplexity 1.745)
#  28%|███████████▍                            | 569/2000 [02:03<03:47,  6.28it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-12570.pkl
#  96%|█████████████████████████████████████▌ | 1924/2000 [07:04<00:12,  6.15it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-13925.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:21<00:00,  4.54it/s]
# INFO:crf:Average learning speed: 5.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.24it/s]
# INFO:eval:Cross-entropy: 0.5487 nats (= perplexity 1.731)
#  43%|█████████████████▏                      | 859/2000 [03:06<02:51,  6.66it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-14860.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:11<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.21it/s]
# INFO:eval:Cross-entropy: 0.5311 nats (= perplexity 1.701)
#   0%|                                          | 4/2000 [00:00<04:51,  6.85it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-16005.pkl
#  70%|███████████████████████████▍           | 1409/2000 [05:01<02:07,  4.64it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-17410.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:08<00:00,  4.66it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.16it/s]
# INFO:eval:Cross-entropy: 0.5266 nats (= perplexity 1.693)
#  18%|███████▏                                | 359/2000 [01:15<04:08,  6.61it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-18360.pkl
#  87%|█████████████████████████████████▉     | 1739/2000 [06:15<00:57,  4.56it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-19740.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:12<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 5.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.32it/s]
# INFO:eval:Cross-entropy: 0.5233 nats (= perplexity 1.688)
#  34%|█████████████▍                          | 672/2000 [02:26<04:17,  5.15it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-20675.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:18<00:00,  4.56it/s]
# INFO:crf:Average learning speed: 5.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.38it/s]
# INFO:eval:Cross-entropy: 0.5096 nats (= perplexity 1.665)
#   0%|                                          | 4/2000 [00:00<06:07,  5.44it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-22005.pkl
#  70%|███████████████████████████▏           | 1394/2000 [05:01<02:02,  4.94it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-23395.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:16<00:00,  4.58it/s]
# INFO:crf:Average learning speed: 5.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.28it/s]
# INFO:eval:Cross-entropy: 0.5077 nats (= perplexity 1.662)
#  16%|██████▍                                 | 324/2000 [01:08<04:33,  6.13it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-24325.pkl
#  85%|█████████████████████████████████      | 1698/2000 [06:08<01:06,  4.53it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-25700.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:16<00:00,  4.59it/s]
# INFO:crf:Average learning speed: 5.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:39<00:00, 10.03it/s]
# INFO:eval:Cross-entropy: 0.5014 nats (= perplexity 1.651)
#  30%|████████████▏                           | 609/2000 [02:13<04:11,  5.54it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-26610.pkl
#  99%|██████████████████████████████████████▍| 1974/2000 [07:14<00:04,  5.97it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_reg02-27975.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:19<00:00,  4.55it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.36it/s]
# INFO:eval:Cross-entropy: 0.5013 nats (= perplexity 1.651)
# INFO:hmm:Saved model to ../models/en_crf_birnn_reg02.pkl
# INFO:eval:Total training time: 2:06:11
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:48<00:00, 20.38it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_reg02_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.55it/s]
# INFO:eval:Cross-entropy: 0.5013 nats (= perplexity 1.651)
# 100%|█████████████████████████████████████████| 996/996 [00:48<00:00, 20.57it/s]
# INFO:eval:Tagging accuracy: all: 81.081%, known: 82.162%, seen: 66.176%, novel: 72.924%
# INFO:eval:===

# %% [markdown]
# minibatch

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-10.txt --lr 0.01 --reg 0.1 \
    --batch_size 1 --model ../models/en_crf_birnn_mb1.pkl
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 1296 = 8*19 + 8*19 + 8*69 + 8*53 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.32it/s]
# INFO:eval:Cross-entropy: 3.2114 nats (= perplexity 24.815)
#  46%|██████████████████▏                     | 912/2000 [03:23<03:51,  4.71it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-913.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:16<00:00,  4.58it/s]
# INFO:crf:Average learning speed: 3.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.10it/s]
# INFO:eval:Cross-entropy: 0.6839 nats (= perplexity 1.982)
#   0%|                                                  | 0/2000 [00:00<?, ?it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-2001.pkl
#  69%|██████████████████████████▊            | 1372/2000 [04:59<02:17,  4.56it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-3373.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:18<00:00,  4.56it/s]
# INFO:crf:Average learning speed: 4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.31it/s]
# INFO:eval:Cross-entropy: 0.6172 nats (= perplexity 1.854)
#  15%|█████▊                                  | 293/2000 [01:04<05:43,  4.98it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-4294.pkl
#  83%|████████████████████████████████▍      | 1662/2000 [06:04<01:17,  4.37it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-5663.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:17<00:00,  4.57it/s]
# INFO:crf:Average learning speed: 4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.19it/s]
# INFO:eval:Cross-entropy: 0.5720 nats (= perplexity 1.772)
#  30%|████████████▏                           | 609/2000 [02:10<03:26,  6.73it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-6610.pkl
#  99%|██████████████████████████████████████▋| 1986/2000 [07:10<00:03,  3.78it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-7987.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:13<00:00,  4.62it/s]
# INFO:crf:Average learning speed: 4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.07it/s]
# INFO:eval:Cross-entropy: 0.5550 nats (= perplexity 1.742)
#  45%|█████████████████▉                      | 899/2000 [03:18<03:12,  5.72it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-8900.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:17<00:00,  4.57it/s]
# INFO:crf:Average learning speed: 4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.12it/s]
# INFO:eval:Cross-entropy: 0.5362 nats (= perplexity 1.709)
#   0%|                                                  | 0/2000 [00:00<?, ?it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-10001.pkl
#  66%|█████████████████████████▋             | 1317/2000 [05:00<02:38,  4.32it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-11318.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:37<00:00,  4.37it/s]
# INFO:crf:Average learning speed: 3.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:42<00:00,  9.70it/s]
# INFO:eval:Cross-entropy: 0.5305 nats (= perplexity 1.700)
#   9%|███▍                                    | 171/2000 [00:39<08:41,  3.51it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-12172.pkl
#  77%|█████████████████████████████▊         | 1531/2000 [05:40<01:29,  5.22it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-13532.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:28<00:00,  4.46it/s]
# INFO:crf:Average learning speed: 3.7 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:39<00:00, 10.02it/s]
# INFO:eval:Cross-entropy: 0.5053 nats (= perplexity 1.657)
#  21%|████████▏                               | 412/2000 [01:32<06:10,  4.29it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-14413.pkl
#  86%|█████████████████████████████████▌     | 1721/2000 [06:32<00:58,  4.74it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-15722.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:36<00:00,  4.38it/s]
# INFO:crf:Average learning speed: 3.7 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.07it/s]
# INFO:eval:Cross-entropy: 0.5043 nats (= perplexity 1.656)
#  32%|████████████▊                           | 640/2000 [02:16<04:57,  4.57it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-16641.pkl
#  99%|██████████████████████████████████████▌| 1978/2000 [07:17<00:04,  4.77it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-17979.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:22<00:00,  4.52it/s]
# INFO:crf:Average learning speed: 3.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:39<00:00, 10.01it/s]
# INFO:eval:Cross-entropy: 0.4920 nats (= perplexity 1.636)
#  44%|█████████████████▌                      | 875/2000 [03:14<04:38,  4.04it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-18876.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:23<00:00,  4.51it/s]
# INFO:crf:Average learning speed: 3.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.10it/s]
# INFO:eval:Cross-entropy: 0.4839 nats (= perplexity 1.622)
#   0%|                                                  | 0/2000 [00:00<?, ?it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-20001.pkl
#  67%|██████████████████████████▎            | 1348/2000 [05:00<02:13,  4.88it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-21349.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:22<00:00,  4.52it/s]
# INFO:crf:Average learning speed: 3.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.17it/s]
# INFO:eval:Cross-entropy: 0.4797 nats (= perplexity 1.616)
#  13%|█████▎                                  | 265/2000 [00:59<06:45,  4.27it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-22266.pkl
#  82%|███████████████████████████████▉       | 1635/2000 [06:00<01:09,  5.24it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_mb1-23636.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:20<00:00,  4.54it/s]
# INFO:crf:Average learning speed: 3.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.24it/s]
# INFO:eval:Cross-entropy: 0.4840 nats (= perplexity 1.623)
# INFO:hmm:Saved model to ../models/en_crf_birnn_mb1.pkl
# INFO:eval:Total training time: 1:49:55
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:50<00:00, 19.89it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_mb1_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.36it/s]
# INFO:eval:Cross-entropy: 0.4840 nats (= perplexity 1.623)
# 100%|█████████████████████████████████████████| 996/996 [00:50<00:00, 19.92it/s]
# INFO:eval:Tagging accuracy: all: 81.782%, known: 82.908%, seen: 65.651%, novel: 73.789%
# INFO:eval:===

# %% [markdown]
# lexicons

# %%
# !python3 ./tag.py ../data/endev --train ../data/ensup \
    --crf --rnn_dim 8 \
    --model ../models/en_crf_birnn_onehot.pkl \
    --lr 0.01 --reg 0.1 --batch_size 5 --max_steps 50000
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:crf_backprop:Parameters: 300240 = 8*12475 + 8*12475 + 8*69 + 8*12509 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [02:19<00:00,  7.13it/s]
# INFO:eval:Cross-entropy: 3.0803 nats (= perplexity 21.765)
#  26%|██████████▍                             | 519/2000 [02:39<05:31,  4.46it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-520.pkl
#  72%|████████████████████████████▏          | 1444/2000 [07:40<01:49,  5.06it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-1445.pkl
# 100%|███████████████████████████████████████| 2000/2000 [10:41<00:00,  3.12it/s]
# INFO:crf:Average learning speed: 1.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [02:17<00:00,  7.27it/s]
# INFO:eval:Cross-entropy: 0.4230 nats (= perplexity 1.527)
#   0%|                                          | 4/2000 [00:01<08:47,  3.79it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-2005.pkl
#  46%|██████████████████▌                     | 929/2000 [05:01<04:19,  4.13it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-2930.pkl
#  93%|████████████████████████████████████▎  | 1859/2000 [10:03<00:38,  3.69it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-3860.pkl
# 100%|███████████████████████████████████████| 2000/2000 [10:55<00:00,  3.05it/s]
# INFO:crf:Average learning speed: 1.4 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [02:16<00:00,  7.28it/s]
# INFO:eval:Cross-entropy: 0.1969 nats (= perplexity 1.218)
#  18%|███████▏                                | 359/2000 [01:51<05:59,  4.56it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-4360.pkl
#  64%|█████████████████████████              | 1284/2000 [06:52<03:09,  3.77it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-5285.pkl
# 100%|███████████████████████████████████████| 2000/2000 [10:44<00:00,  3.11it/s]
# INFO:crf:Average learning speed: 0.82 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [02:20<00:00,  7.07it/s]
# INFO:eval:Cross-entropy: 0.1730 nats (= perplexity 1.189)
#   0%|                                          | 4/2000 [00:01<09:08,  3.64it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-6005.pkl
#  46%|██████████████████▎                     | 914/2000 [05:02<04:49,  3.76it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-6915.pkl
#  91%|███████████████████████████████████▌   | 1824/2000 [10:01<00:53,  3.26it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-7825.pkl
# 100%|███████████████████████████████████████| 2000/2000 [11:08<00:00,  2.99it/s]
# INFO:crf:Average learning speed: 0.89 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [02:17<00:00,  7.23it/s]
# INFO:eval:Cross-entropy: 0.1619 nats (= perplexity 1.176)
#  15%|██████▏                                 | 308/2000 [01:36<06:58,  4.05it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-8310.pkl
#  62%|████████████████████████               | 1234/2000 [06:38<02:32,  5.03it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-9235.pkl
# 100%|███████████████████████████████████████| 2000/2000 [10:48<00:00,  3.08it/s]
# INFO:crf:Average learning speed: 0.39 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [02:21<00:00,  7.05it/s]
# INFO:eval:Cross-entropy: 0.1575 nats (= perplexity 1.171)
#   0%|                                          | 4/2000 [00:00<04:36,  7.21it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-10005.pkl
#  46%|██████████████████▌                     | 929/2000 [05:01<05:07,  3.48it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-10930.pkl
#  92%|███████████████████████████████████▋   | 1833/2000 [10:01<00:40,  4.17it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_onehot-11835.pkl
# 100%|███████████████████████████████████████| 2000/2000 [10:55<00:00,  3.05it/s]
# INFO:crf:Average learning speed: 0.48 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [02:19<00:00,  7.13it/s]
# INFO:eval:Cross-entropy: 0.1627 nats (= perplexity 1.177)
# INFO:hmm:Saved model to ../models/en_crf_birnn_onehot.pkl
# INFO:eval:Total training time: 1:21:27
# ---
# 100%|█████████████████████████████████████████| 996/996 [01:11<00:00, 13.94it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_onehot_endev.output
# 100%|█████████████████████████████████████████| 996/996 [02:21<00:00,  7.06it/s]
# INFO:eval:Cross-entropy: 0.1627 nats (= perplexity 1.177)
# 100%|█████████████████████████████████████████| 996/996 [01:09<00:00, 14.36it/s]
# INFO:eval:Tagging accuracy: all: 94.651%, known: 97.042%, seen: nan%, novel: 69.877%
# INFO:eval:===

# %%
# !python3 tag.py ../data/endev --train ../data/ensup \
    --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-10.txt \
    --model ../models/en_crf_birnn_words10.pkl \
    --lr 0.01 --reg 0.1 --batch_size 5 --max_steps 50000
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-10.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 1296 = 8*19 + 8*19 + 8*69 + 8*53 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.48it/s]
# INFO:eval:Cross-entropy: 3.2114 nats (= perplexity 24.815)
#  46%|██████████████████▎                     | 914/2000 [03:25<03:07,  5.80it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-915.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:23<00:00,  4.51it/s]
# INFO:crf:Average learning speed: 1.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.31it/s]
# INFO:eval:Cross-entropy: 0.9564 nats (= perplexity 2.602)
#   0%|                                          | 4/2000 [00:00<05:18,  6.27it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-2005.pkl
#  68%|██████████████████████████▌            | 1364/2000 [05:01<01:53,  5.61it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-3365.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:24<00:00,  4.50it/s]
# INFO:crf:Average learning speed: 3.8 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.42it/s]
# INFO:eval:Cross-entropy: 0.7212 nats (= perplexity 2.057)
#  14%|█████▊                                  | 288/2000 [01:01<05:41,  5.01it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-4290.pkl
#  86%|█████████████████████████████████▍     | 1714/2000 [06:01<00:41,  6.88it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-5715.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:04<00:00,  4.71it/s]
# INFO:crf:Average learning speed: 4.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.35it/s]
# INFO:eval:Cross-entropy: 0.6522 nats (= perplexity 1.920)
#  33%|█████████████▏                          | 659/2000 [02:22<04:10,  5.34it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-6660.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:19<00:00,  4.55it/s]
# INFO:crf:Average learning speed: 4.6 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.21it/s]
# INFO:eval:Cross-entropy: 0.6000 nats (= perplexity 1.822)
#   0%|                                          | 4/2000 [00:00<03:20,  9.94it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-8005.pkl
#  69%|██████████████████████████▉            | 1383/2000 [05:01<02:10,  4.73it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-9385.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:13<00:00,  4.61it/s]
# INFO:crf:Average learning speed: 4.7 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.46it/s]
# INFO:eval:Cross-entropy: 0.5714 nats (= perplexity 1.771)
#  17%|██████▉                                 | 349/2000 [01:12<06:00,  4.58it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-10350.pkl
#  84%|████████████████████████████████▊      | 1684/2000 [06:13<01:08,  4.63it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-11685.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:17<00:00,  4.57it/s]
# INFO:crf:Average learning speed: 4.9 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.29it/s]
# INFO:eval:Cross-entropy: 0.5563 nats (= perplexity 1.744)
#  33%|█████████████▏                          | 659/2000 [02:19<04:17,  5.20it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-12660.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:01<00:00,  4.75it/s]
# INFO:crf:Average learning speed: 5.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.43it/s]
# INFO:eval:Cross-entropy: 0.5490 nats (= perplexity 1.732)
#   0%|                                          | 4/2000 [00:00<03:47,  8.79it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-14005.pkl
#  69%|██████████████████████████▉            | 1379/2000 [05:00<01:41,  6.11it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-15380.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:16<00:00,  4.58it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:36<00:00, 10.37it/s]
# INFO:eval:Cross-entropy: 0.5299 nats (= perplexity 1.699)
#  15%|██████                                  | 303/2000 [01:07<06:24,  4.41it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-16305.pkl
#  86%|█████████████████████████████████▍     | 1714/2000 [06:07<00:49,  5.75it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-17715.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:15<00:00,  4.60it/s]
# INFO:crf:Average learning speed: 5.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.45it/s]
# INFO:eval:Cross-entropy: 0.5262 nats (= perplexity 1.693)
#  33%|█████████████▏                          | 659/2000 [02:18<03:32,  6.30it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-18660.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:08<00:00,  4.67it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.39it/s]
# INFO:eval:Cross-entropy: 0.5231 nats (= perplexity 1.687)
#   0%|                                          | 3/2000 [00:00<07:27,  4.47it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-20005.pkl
#  69%|██████████████████████████▉            | 1384/2000 [05:01<02:09,  4.74it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-21385.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:11<00:00,  4.63it/s]
# INFO:crf:Average learning speed: 5.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.57it/s]
# INFO:eval:Cross-entropy: 0.5083 nats (= perplexity 1.662)
#  19%|███████▍                                | 372/2000 [01:16<06:37,  4.09it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-22375.pkl
#  89%|██████████████████████████████████▉    | 1789/2000 [06:16<00:42,  5.01it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-23790.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:03<00:00,  4.72it/s]
# INFO:crf:Average learning speed: 5.7 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.06it/s]
# INFO:eval:Cross-entropy: 0.5076 nats (= perplexity 1.661)
#  36%|██████████████▍                         | 719/2000 [02:34<03:20,  6.38it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-24720.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:18<00:00,  4.56it/s]
# INFO:crf:Average learning speed: 5.3 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.18it/s]
# INFO:eval:Cross-entropy: 0.5001 nats (= perplexity 1.649)
#   0%|                                          | 4/2000 [00:00<07:29,  4.44it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-26005.pkl
#  71%|███████████████████████████▋           | 1419/2000 [05:01<01:16,  7.56it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-27420.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:03<00:00,  4.72it/s]
# INFO:crf:Average learning speed: 5.1 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:35<00:00, 10.47it/s]
# INFO:eval:Cross-entropy: 0.4979 nats (= perplexity 1.645)
#  20%|███████▉                                | 394/2000 [01:23<03:26,  7.79it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-28395.pkl
#  89%|██████████████████████████████████▉    | 1789/2000 [06:23<00:45,  4.63it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-29790.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:09<00:00,  4.66it/s]
# INFO:crf:Average learning speed: 5.5 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:34<00:00, 10.58it/s]
# INFO:eval:Cross-entropy: 0.4927 nats (= perplexity 1.637)
#  37%|██████████████▉                         | 744/2000 [02:40<03:49,  5.48it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_words10-30745.pkl
# 100%|███████████████████████████████████████| 2000/2000 [07:09<00:00,  4.65it/s]
# INFO:crf:Average learning speed: 5.2 (estimated training loss reduction per example)
# 100%|█████████████████████████████████████████| 996/996 [01:39<00:00, 10.01it/s]
# INFO:eval:Cross-entropy: 0.4956 nats (= perplexity 1.641)
# INFO:hmm:Saved model to ../models/en_crf_birnn_words10.pkl
# INFO:eval:Total training time: 2:22:37
# ---
# 100%|█████████████████████████████████████████| 996/996 [00:49<00:00, 20.28it/s]
# INFO:eval:Wrote tagging to ../models/en_crf_birnn_words10_endev.output
# 100%|█████████████████████████████████████████| 996/996 [01:38<00:00, 10.15it/s]
# INFO:eval:Cross-entropy: 0.4956 nats (= perplexity 1.641)
# 100%|█████████████████████████████████████████| 996/996 [00:49<00:00, 20.22it/s]
# INFO:eval:Tagging accuracy: all: 81.302%, known: 82.272%, seen: 67.542%, novel: 74.308%
# INFO:eval:===

# %%
# !python3 tag.py ../data/endev --train ../data/ensup \
    --crf --rnn_dim 8 \
    --lexicon ../lexicons/words-200.txt \
    --model ../models/en_crf_birnn_custom.pkl \
    --lr 0.01 --reg 0.1 --batch_size 5 --max_steps 50000
# Out:
# INFO:corpus:Read 95936 tokens from ensup
# INFO:corpus:Created 26 tag types
# INFO:corpus:Created 12466 word types
# INFO:corpus:Read 23949 tokens from endev
# INFO:corpus:Created 23 tag types
# INFO:corpus:Created 4959 word types
# INFO:lexicon:From words-200.txt, got embeddings for 7624 of 12466 previously known types + 777 new seen types
# INFO:crf_backprop:Parameters: 5856 = 8*209 + 8*209 + 8*69 + 8*243 + 8 + 8
# 100%|█████████████████████████████████████████| 996/996 [01:37<00:00, 10.24it/s]
# INFO:eval:Cross-entropy: 3.1039 nats (= perplexity 22.285)
#  46%|██████████████████▍                     | 924/2000 [03:22<03:41,  4.86it/s]INFO:hmm:Saved model to ../models/en_crf_birnn_custom-925.pkl
#  47%|██████████████████▋                     | 934/2000 [03:25<03:38,  4.87it/s]^C
